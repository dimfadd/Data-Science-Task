# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
myDirFiles = "/content/drive/MyDrive/Digital skola/dataframe"
os.chdir(myDirFiles)

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dummy_data_2 = {
    'col1': [1, 3, 5, 6],
    'col2': [2, 3, 2, 1],
}
df_dummy_2 = pd.DataFrame(dummy_data_2)
df_dummy_2
# Out:
#    col1  col2
# 0     1     2
# 1     3     3
# 2     5     2
# 3     6     1

# %%
df_dummy_2.sum()
# Out:
# col1    15
# col2     8
# dtype: int64

# %%
dummy_data_3 = {
    'col1': [1, 3, 5, 6],
    'col2': [2, 3, 2, 1],
}
df_dummy_3 = pd.DataFrame(
    dummy_data_3,
    index=['Umur', 'Tinggi', 'Berat', 'Bulan_Lahir']
)

df_dummy_3
# Out:
#              col1  col2
# Umur            1     2
# Tinggi          3     3
# Berat           5     2
# Bulan_Lahir     6     1

# %%
my_filter = df_dummy_3["col1"] > 2
df_dummy_3.loc[my_filter, ["col1"]]
# Out:
#              col1
# Tinggi          3
# Berat           5
# Bulan_Lahir     6

# %%
df_dummy_3.loc[df_dummy_3["col1"] > 2, "col1"] = "Besar"

# %%
df_dummy_3
# Out:
#               col1  col2
# Umur             1     2
# Tinggi       Besar     3
# Berat        Besar     2
# Bulan_Lahir  Besar     1

# %%
dummy_data = {
    'col1': ['A', 'A', 'B', None, 'D', 'C'],
    'col2': [2, None, 9, 8, 7, 4],
    'col3': [0, 1, 9, 4, 2, None],
    'col4': [None, 'B', 'c', None, 'e', 'F']
}

df_dummy = pd.DataFrame(dummy_data)
df_dummy
# Out:
#    col1  col2  col3  col4
# 0     A   2.0   0.0  None
# 1     A   NaN   1.0     B
# 2     B   9.0   9.0     c
# 3  None   8.0   4.0  None
# 4     D   7.0   2.0     e
# 5     C   4.0   NaN     F

# %%
df_dummy.sort_values("col2")
# Out:
#    col1  col2  col3  col4
# 0     A   2.0   0.0  None
# 5     C   4.0   NaN     F
# 4     D   7.0   2.0     e
# 3  None   8.0   4.0  None
# 2     B   9.0   9.0     c
# 1     A   NaN   1.0     B

# %%
df_dummy.col4.value_counts(dropna=False)
# Out:
# None    2
# B       1
# c       1
# e       1
# F       1
# Name: col4, dtype: int64

# %% [markdown]
# # Check NaN Values

# %%
df_dummy.isna()
# Out:
#     col1   col2   col3   col4
# 0  False  False  False   True
# 1  False   True  False  False
# 2  False  False  False  False
# 3   True  False  False   True
# 4  False  False  False  False
# 5  False  False   True  False

# %%
~df_dummy.isna()
# Out:
#     col1   col2   col3   col4
# 0   True   True   True  False
# 1   True  False   True   True
# 2   True   True   True   True
# 3  False   True   True  False
# 4   True   True   True   True
# 5   True   True  False   True

# %%
df_dummy.notna()
# Out:
#     col1   col2   col3   col4
# 0   True   True   True  False
# 1   True  False   True   True
# 2   True   True   True   True
# 3  False   True   True  False
# 4   True   True   True   True
# 5   True   True  False   True

# %%
display(df_dummy.isna())
df_dummy.isna().sum()
# Out:
#     col1   col2   col3   col4
# 0  False  False  False   True
# 1  False   True  False  False
# 2  False  False  False  False
# 3   True  False  False   True
# 4  False  False  False  False
# 5  False  False   True  False
# col1    1
# col2    1
# col3    1
# col4    2
# dtype: int64

# %%
display(df_dummy.notna())
df_dummy.notna().sum()

# %%
df_dummy
# Out:
#    col1  col2  col3  col4
# 0     A   2.0   0.0  None
# 1     A   NaN   1.0     B
# 2     B   9.0   9.0     c
# 3  None   8.0   4.0  None
# 4     D   7.0   2.0     e
# 5     C   4.0   NaN     F

# %%
df_dummy.fillna('Loss') # temporarily, just for view
# if want to save it permanently, add inplace = True
# or
# df_dummy = df_dummy.fillna('Loss')
# Out:
#    col1  col2  col3  col4
# 0     A   2.0   0.0  Loss
# 1     A  Loss   1.0     B
# 2     B   9.0   9.0     c
# 3  Loss   8.0   4.0  Loss
# 4     D   7.0   2.0     e
# 5     C   4.0  Loss     F

# %%
df_dummy
# Out:
#    col1  col2  col3  col4
# 0     A   2.0   0.0  None
# 1     A   NaN   1.0     B
# 2     B   9.0   9.0     c
# 3  None   8.0   4.0  None
# 4     D   7.0   2.0     e
# 5     C   4.0   NaN     F

# %%
df_dummy

# %%
# nama kolom harus tanpa spasi
df_dummy.col1.fillna(method='bfill')
# Out:
# 0    A
# 1    A
# 2    B
# 3    D
# 4    D
# 5    C
# Name: col1, dtype: object

# %%
df_dummy.col1.fillna(method='ffill')
# Out:
# 0    A
# 1    A
# 2    B
# 3    B
# 4    D
# 5    C
# Name: col1, dtype: object

# %%
df_dummy.col2.mean()
# Out:
# 6.0

# %%
# dict comperhension
fillna_rules = {
    'col1': 'C',
    'col2': df_dummy.col2.mean(),
    'col3': df_dummy.col3.max(),
    'col4': df_dummy.col4.fillna(method = 'ffill')
}
df_dummy.fillna(fillna_rules)
# Out:
#   col1  col2  col3  col4
# 0    A   2.0   0.0  None
# 1    A   6.0   1.0     B
# 2    B   9.0   9.0     c
# 3    C   8.0   4.0     c
# 4    D   7.0   2.0     e
# 5    C   4.0   9.0     F

# %%
df_dummy
# Out:
#    col1  col2  col3  col4
# 0     A   2.0   0.0  None
# 1     A   NaN   1.0     B
# 2     B   9.0   9.0     c
# 3  None   8.0   4.0  None
# 4     D   7.0   2.0     e
# 5     C   4.0   NaN     F

# %%
df_dummy.col4.fillna(method = 'ffill')
# Out:
# 0    None
# 1       B
# 2       c
# 3       c
# 4       e
# 5       F
# Name: col4, dtype: object

# %% [markdown]
# # Iris Dataset

# %%
#sns.load_dataset('iris')

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
myColumns = ['Species', 'SepalLengthCm', 'SepalWidthCm']
pd.sort_by(myColumns[3, 2], ascending = [True, True])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-558f9ae507ad> in <cell line: 2>()
#       1 myColumns = ['Species', 'SepalLengthCm', 'SepalWidthCm']
# ----> 2 pd.sort_by(myColumns[3, 2], ascending = [True, True])
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'sort_by'

# %%
df.drop('Id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-120684e17b03> in <cell line: 1>()
# ----> 1 df.drop('Id')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
#df.drop('Id') #==> wrong, by default axis = 0 (row wise)
df.drop('Id', axis = 1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.drop('Id', axis = 1, inplace = True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.notna().sum()
# Out:
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
len(df)
# Out:
# 150

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # Sorting in DataFrame

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
display(df['SepalLengthCm'])
type(df['SepalLengthCm'])
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64
# pandas.core.series.Series

# %%
display(df[['SepalLengthCm']])
type(df[['SepalLengthCm']])
# Out:
#      SepalLengthCm
# 0              5.1
# 1              4.9
# 2              4.7
# 3              4.6
# 4              5.0
# ..             ...
# 145            6.7
# 146            6.3
# 147            6.5
# 148            6.2
# 149            5.9
#
# [150 rows x 1 columns]
# pandas.core.frame.DataFrame

# %%
df[['SepalLengthCm', 'PetalLengthCm']]
# Out:
#      SepalLengthCm  PetalLengthCm
# 0              5.1            1.4
# 1              4.9            1.4
# 2              4.7            1.3
# 3              4.6            1.5
# 4              5.0            1.4
# ..             ...            ...
# 145            6.7            5.2
# 146            6.3            5.0
# 147            6.5            5.2
# 148            6.2            5.4
# 149            5.9            5.1
#
# [150 rows x 2 columns]

# %%
viewColumns = ['Species', 'SepalLengthCm', 'SepalWidthCm']
sortByColumns = ['Species', 'SepalLengthCm']

df.sort_values(by=sortByColumns, ascending=True)[viewColumns]
# Out:
#             Species  SepalLengthCm  SepalWidthCm
# 13      Iris-setosa            4.3           3.0
# 8       Iris-setosa            4.4           2.9
# 38      Iris-setosa            4.4           3.0
# 42      Iris-setosa            4.4           3.2
# 41      Iris-setosa            4.5           2.3
# ..              ...            ...           ...
# 117  Iris-virginica            7.7           3.8
# 118  Iris-virginica            7.7           2.6
# 122  Iris-virginica            7.7           2.8
# 135  Iris-virginica            7.7           3.0
# 131  Iris-virginica            7.9           3.8
#
# [150 rows x 3 columns]

# %%
viewColumns   = ['Species', 'SepalLengthCm', 'SepalWidthCm']
sortByColumns = ['Species', 'SepalLengthCm']

df.sort_values(by=sortByColumns, ascending=True, ignore_index=True)[viewColumns]
# Out:
#             Species  SepalLengthCm  SepalWidthCm
# 0       Iris-setosa            4.3           3.0
# 1       Iris-setosa            4.4           2.9
# 2       Iris-setosa            4.4           3.0
# 3       Iris-setosa            4.4           3.2
# 4       Iris-setosa            4.5           2.3
# ..              ...            ...           ...
# 145  Iris-virginica            7.7           3.8
# 146  Iris-virginica            7.7           2.6
# 147  Iris-virginica            7.7           2.8
# 148  Iris-virginica            7.7           3.0
# 149  Iris-virginica            7.9           3.8
#
# [150 rows x 3 columns]

# %% [markdown]
# # Filtering DataFrame

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.Species.nunique()
# Out:
# 3

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df['Species'].value_counts(dropna=False)
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df.Species == 'Iris-versicolor'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Species, Length: 150, dtype: bool

# %%
df.SepalLengthCm >= 5.0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: SepalLengthCm, Length: 150, dtype: bool

# %%
df.Species == 'Iris-setosa'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Species, Length: 150, dtype: bool

# %%
versicolor_mask = (df.Species == 'Iris-versicolor')
df[versicolor_mask][viewColumns]
# Out:
#             Species  SepalLengthCm  SepalWidthCm
# 50  Iris-versicolor            7.0           3.2
# 51  Iris-versicolor            6.4           3.2
# 52  Iris-versicolor            6.9           3.1
# 53  Iris-versicolor            5.5           2.3
# 54  Iris-versicolor            6.5           2.8
# 55  Iris-versicolor            5.7           2.8
# 56  Iris-versicolor            6.3           3.3
# 57  Iris-versicolor            4.9           2.4
# 58  Iris-versicolor            6.6           2.9
# 59  Iris-versicolor            5.2           2.7
# 60  Iris-versicolor            5.0           2.0
# 61  Iris-versicolor            5.9           3.0
# 62  Iris-versicolor            6.0           2.2
# 63  Iris-versicolor            6.1           2.9
# 64  Iris-versicolor            5.6           2.9
# 65  Iris-versicolor            6.7           3.1
# 66  Iris-versicolor            5.6           3.0
# 67  Iris-versicolor            5.8           2.7
# ...

# %%
my_filter = (df.Species == 'Iris-setosa') & (df.SepalLengthCm < 5.0)
viewColumns = ['Species', 'SepalLengthCm']
df[my_filter][viewColumns]
# Out:
#         Species  SepalLengthCm
# 1   Iris-setosa            4.9
# 2   Iris-setosa            4.7
# 3   Iris-setosa            4.6
# 6   Iris-setosa            4.6
# 8   Iris-setosa            4.4
# 9   Iris-setosa            4.9
# 11  Iris-setosa            4.8
# 12  Iris-setosa            4.8
# 13  Iris-setosa            4.3
# 22  Iris-setosa            4.6
# 24  Iris-setosa            4.8
# 29  Iris-setosa            4.7
# 30  Iris-setosa            4.8
# 34  Iris-setosa            4.9
# 37  Iris-setosa            4.9
# 38  Iris-setosa            4.4
# 41  Iris-setosa            4.5
# 42  Iris-setosa            4.4
# 45  Iris-setosa            4.8
# 47  Iris-setosa            4.6

# %%
saringanQu = (df.Species == 'Iris-setosa') | (df.Species == 'Iris-versicolor')
df[saringanQu][viewColumns]
# Out:
#             Species  SepalLengthCm
# 0       Iris-setosa            5.1
# 1       Iris-setosa            4.9
# 2       Iris-setosa            4.7
# 3       Iris-setosa            4.6
# 4       Iris-setosa            5.0
# ..              ...            ...
# 95  Iris-versicolor            5.7
# 96  Iris-versicolor            5.7
# 97  Iris-versicolor            6.2
# 98  Iris-versicolor            5.1
# 99  Iris-versicolor            5.7
#
# [100 rows x 2 columns]

# %%
2 != 3
# Out:
# True

# %%
my_filter = df.Species == 'Iris-virginica'
df[~my_filter] # ekivalen, saya mau setosa dan versicolor

# my_filter = (df.Species == 'Iris-setosa') | (df.Species == 'Iris-versicolor')
# df[my_filter]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0             5.1           3.5            1.4           0.2      Iris-setosa
# 1             4.9           3.0            1.4           0.2      Iris-setosa
# 2             4.7           3.2            1.3           0.2      Iris-setosa
# 3             4.6           3.1            1.5           0.2      Iris-setosa
# 4             5.0           3.6            1.4           0.2      Iris-setosa
# ..            ...           ...            ...           ...              ...
# 95            5.7           3.0            4.2           1.2  Iris-versicolor
# 96            5.7           2.9            4.2           1.3  Iris-versicolor
# 97            6.2           2.9            4.3           1.3  Iris-versicolor
# 98            5.1           2.5            3.0           1.1  Iris-versicolor
# 99            5.7           2.8            4.1           1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
my_filter = df.Species != 'Iris-virginica'
df[my_filter] # ekivalen, saya mau setosa dan versicolor

# my_filter = (df.Species == 'Iris-setosa') | (df.Species == 'Iris-versicolor')
# df[my_filter]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0             5.1           3.5            1.4           0.2      Iris-setosa
# 1             4.9           3.0            1.4           0.2      Iris-setosa
# 2             4.7           3.2            1.3           0.2      Iris-setosa
# 3             4.6           3.1            1.5           0.2      Iris-setosa
# 4             5.0           3.6            1.4           0.2      Iris-setosa
# ..            ...           ...            ...           ...              ...
# 95            5.7           3.0            4.2           1.2  Iris-versicolor
# 96            5.7           2.9            4.2           1.3  Iris-versicolor
# 97            6.2           2.9            4.3           1.3  Iris-versicolor
# 98            5.1           2.5            3.0           1.1  Iris-versicolor
# 99            5.7           2.8            4.1           1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
mySpecies = ['Iris-versicolor', 'Iris-setosa']
df[df.Species.isin(mySpecies)]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0             5.1           3.5            1.4           0.2      Iris-setosa
# 1             4.9           3.0            1.4           0.2      Iris-setosa
# 2             4.7           3.2            1.3           0.2      Iris-setosa
# 3             4.6           3.1            1.5           0.2      Iris-setosa
# 4             5.0           3.6            1.4           0.2      Iris-setosa
# ..            ...           ...            ...           ...              ...
# 95            5.7           3.0            4.2           1.2  Iris-versicolor
# 96            5.7           2.9            4.2           1.3  Iris-versicolor
# 97            6.2           2.9            4.3           1.3  Iris-versicolor
# 98            5.1           2.5            3.0           1.1  Iris-versicolor
# 99            5.7           2.8            4.1           1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
mySpecies = ['Iris-versicolor', 'Iris-setosa']
df[~df.Species.isin(mySpecies)]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 100            6.3           3.3            6.0           2.5  Iris-virginica
# 101            5.8           2.7            5.1           1.9  Iris-virginica
# 102            7.1           3.0            5.9           2.1  Iris-virginica
# 103            6.3           2.9            5.6           1.8  Iris-virginica
# 104            6.5           3.0            5.8           2.2  Iris-virginica
# 105            7.6           3.0            6.6           2.1  Iris-virginica
# 106            4.9           2.5            4.5           1.7  Iris-virginica
# 107            7.3           2.9            6.3           1.8  Iris-virginica
# 108            6.7           2.5            5.8           1.8  Iris-virginica
# 109            7.2           3.6            6.1           2.5  Iris-virginica
# 110            6.5           3.2            5.1           2.0  Iris-virginica
# ...

# %%
myFilter = ((df.SepalLengthCm > 2.0 )  &  (df.SepalWidthCm == 3.0)) | (df.Species == 'Iris-virginica')
myFilterI = ........
df[myFilter & myFilterI]

# %% [markdown]
# # .loc & .iloc

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
# nama index df.loc[row_mask, column_mask]
df.loc[10:20]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# 12            4.8           3.0            1.4           0.1  Iris-setosa
# 13            4.3           3.0            1.1           0.1  Iris-setosa
# 14            5.8           4.0            1.2           0.2  Iris-setosa
# 15            5.7           4.4            1.5           0.4  Iris-setosa
# 16            5.4           3.9            1.3           0.4  Iris-setosa
# 17            5.1           3.5            1.4           0.3  Iris-setosa
# 18            5.7           3.8            1.7           0.3  Iris-setosa
# 19            5.1           3.8            1.5           0.3  Iris-setosa
# 20            5.4           3.4            1.7           0.2  Iris-setosa

# %%
df.loc[10:20, 'SepalLengthCm']
# Out:
# 10    5.4
# 11    4.8
# 12    4.8
# 13    4.3
# 14    5.8
# 15    5.7
# 16    5.4
# 17    5.1
# 18    5.7
# 19    5.1
# 20    5.4
# Name: SepalLengthCm, dtype: float64

# %%
df.loc[10:20, ['SepalLengthCm']]
# Out:
#     SepalLengthCm
# 10            5.4
# 11            4.8
# 12            4.8
# 13            4.3
# 14            5.8
# 15            5.7
# 16            5.4
# 17            5.1
# 18            5.7
# 19            5.1
# 20            5.4

# %%
df.loc[10:20, viewColumns]
# Out:
#         Species  SepalLengthCm
# 10  Iris-setosa            5.4
# 11  Iris-setosa            4.8
# 12  Iris-setosa            4.8
# 13  Iris-setosa            4.3
# 14  Iris-setosa            5.8
# 15  Iris-setosa            5.7
# 16  Iris-setosa            5.4
# 17  Iris-setosa            5.1
# 18  Iris-setosa            5.7
# 19  Iris-setosa            5.1
# 20  Iris-setosa            5.4

# %%
viewColumns
# Out:
# ['Species', 'SepalLengthCm']

# %%
my_filter = (df.Species == 'Iris-setosa') & (df.SepalLengthCm < 5.0)
df.loc[my_filter, viewColumns]
# Out:
#         Species  SepalLengthCm
# 1   Iris-setosa            4.9
# 2   Iris-setosa            4.7
# 3   Iris-setosa            4.6
# 6   Iris-setosa            4.6
# 8   Iris-setosa            4.4
# 9   Iris-setosa            4.9
# 11  Iris-setosa            4.8
# 12  Iris-setosa            4.8
# 13  Iris-setosa            4.3
# 22  Iris-setosa            4.6
# 24  Iris-setosa            4.8
# 29  Iris-setosa            4.7
# 30  Iris-setosa            4.8
# 34  Iris-setosa            4.9
# 37  Iris-setosa            4.9
# 38  Iris-setosa            4.4
# 41  Iris-setosa            4.5
# 42  Iris-setosa            4.4
# 45  Iris-setosa            4.8
# 47  Iris-setosa            4.6

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.loc[:10, 'SepalLengthCm':'PetalLengthCm']
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0             5.1           3.5            1.4
# 1             4.9           3.0            1.4
# 2             4.7           3.2            1.3
# 3             4.6           3.1            1.5
# 4             5.0           3.6            1.4
# 5             5.4           3.9            1.7
# 6             4.6           3.4            1.4
# 7             5.0           3.4            1.5
# 8             4.4           2.9            1.4
# 9             4.9           3.1            1.5
# 10            5.4           3.7            1.5

# %%
df_new = df.copy()

# %%
my_filter = (df.Species == 'Iris-setosa') & (df.SepalLengthCm >= 5.0)
df_new.loc[my_filter, ['Species', 'SepalLengthCm']]
# Out:
#         Species  SepalLengthCm
# 0   Iris-setosa            5.1
# 4   Iris-setosa            5.0
# 5   Iris-setosa            5.4
# 7   Iris-setosa            5.0
# 10  Iris-setosa            5.4
# 14  Iris-setosa            5.8
# 15  Iris-setosa            5.7
# 16  Iris-setosa            5.4
# 17  Iris-setosa            5.1
# 18  Iris-setosa            5.7
# 19  Iris-setosa            5.1
# 20  Iris-setosa            5.4
# 21  Iris-setosa            5.1
# 23  Iris-setosa            5.1
# 25  Iris-setosa            5.0
# 26  Iris-setosa            5.0
# 27  Iris-setosa            5.2
# 28  Iris-setosa            5.2
# 31  Iris-setosa            5.4
# 32  Iris-setosa            5.2
# 33  Iris-setosa            5.5
# 35  Iris-setosa            5.0
# 36  Iris-setosa            5.5
# 39  Iris-setosa            5.1
# 40  Iris-setosa            5.0
# 43  Iris-setosa            5.0
# 44  Iris-setosa            5.1
# 46  Iris-setosa            5.1
# 48  Iris-setosa            5.3
# ...

# %%
my_filter = (df.Species == 'Iris-setosa') & (df.SepalLengthCm >= 5.0)
df_new.loc[my_filter, 'Species'] = 'Iris-setosa-large'

# %%
df_new.Species.unique()
# Out:
# array(['Iris-setosa-large', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica'], dtype=object)

# %%
df_new
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
#                Species
# 0    Iris-setosa-large
# 1          Iris-setosa
# 2          Iris-setosa
# 3          Iris-setosa
# 4    Iris-setosa-large
# ..                 ...
# 145     Iris-virginica
# 146     Iris-virginica
# ...

# %%
my_filter = (df.Species == 'Iris-virginica') & (df.PetalWidthCm <= 2.0)
df_new.loc[my_filter, 'Species'] = 'Iris-virginica-small'

# %%
df_new.Species.unique()
# Out:
# array(['Iris-setosa-large', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica-small'], dtype=object)

# %%
df_new

# %%
df

# %%
df.iloc[0:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.iloc[0:11, [1,4]]
# Out:
#     SepalWidthCm      Species
# 0            3.5  Iris-setosa
# 1            3.0  Iris-setosa
# 2            3.2  Iris-setosa
# 3            3.1  Iris-setosa
# 4            3.6  Iris-setosa
# 5            3.9  Iris-setosa
# 6            3.4  Iris-setosa
# 7            3.4  Iris-setosa
# 8            2.9  Iris-setosa
# 9            3.1  Iris-setosa
# 10           3.7  Iris-setosa

# %%
df.iloc[0:11, 1:4]
# Out:
#     SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            3.5            1.4           0.2
# 1            3.0            1.4           0.2
# 2            3.2            1.3           0.2
# 3            3.1            1.5           0.2
# 4            3.6            1.4           0.2
# 5            3.9            1.7           0.4
# 6            3.4            1.4           0.3
# 7            3.4            1.5           0.2
# 8            2.9            1.4           0.2
# 9            3.1            1.5           0.1
# 10           3.7            1.5           0.2

# %%
df.iloc[:12:2, 1:6:2]
# Out:
#     SepalWidthCm  PetalWidthCm
# 0            3.5           0.2
# 2            3.2           0.2
# 4            3.6           0.2
# 6            3.4           0.3
# 8            2.9           0.2
# 10           3.7           0.2

# %%
df.iloc[0:11, viewColumns]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-ded83949118c> in <cell line: 1>()
# ----> 1 df.iloc[0:11, viewColumns]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# -> 1563         tup = self._validate_tuple_indexer(tup)
#    1564         with suppress(IndexingError):
#    1565             return self._getitem_lowerdim(tup)
#
# ...

# %%
df_new = df.copy()

# %%
df_new.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#df.iloc[my_filter.astype(int)]

# %%
df_new.columns

# %%
df_new.iloc[:50, 4] = 'Iris-setosa'.upper()

# %%
df_new.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  IRIS-SETOSA
# 1            4.9           3.0            1.4           0.2  IRIS-SETOSA
# 2            4.7           3.2            1.3           0.2  IRIS-SETOSA
# 3            4.6           3.1            1.5           0.2  IRIS-SETOSA
# 4            5.0           3.6            1.4           0.2  IRIS-SETOSA
# 5            5.4           3.9            1.7           0.4  IRIS-SETOSA
# 6            4.6           3.4            1.4           0.3  IRIS-SETOSA
# 7            5.0           3.4            1.5           0.2  IRIS-SETOSA
# 8            4.4           2.9            1.4           0.2  IRIS-SETOSA
# 9            4.9           3.1            1.5           0.1  IRIS-SETOSA

# %%
# Filtering NaN or null
# reassign columns with loc and iloc

# %% [markdown]
# # Creating Additional Column

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['SepalLengthMm'] = df.SepalLengthCm * 10

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
#      SepalLengthMm
# ...

# %%
df.drop('SepalLengthMm', axis = 1, inplace = True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
myValue = df['SepalLengthCm'] * 10
df.insert(
    loc = 1,
    column = 'SepalLengthMm',
    value = myValue
)

# %%
df
# Out:
#      SepalLengthCm  SepalLengthMm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0              5.1           51.0           3.5            1.4           0.2
# 1              4.9           49.0           3.0            1.4           0.2
# 2              4.7           47.0           3.2            1.3           0.2
# 3              4.6           46.0           3.1            1.5           0.2
# 4              5.0           50.0           3.6            1.4           0.2
# ..             ...            ...           ...            ...           ...
# 145            6.7           67.0           3.0            5.2           2.3
# 146            6.3           63.0           2.5            5.0           1.9
# 147            6.5           65.0           3.0            5.2           2.0
# 148            6.2           62.0           3.4            5.4           2.3
# 149            5.9           59.0           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# ...

# %%
df.drop('SepalLengthMm', axis = 1, inplace = True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
myValue = df['SepalLengthCm'] * 10
df.insert(loc = 2, column = 'SepalLengthMm', value = myValue)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  SepalLengthMm  PetalLengthCm  PetalWidthCm  \
# 0              5.1           3.5           51.0            1.4           0.2
# 1              4.9           3.0           49.0            1.4           0.2
# 2              4.7           3.2           47.0            1.3           0.2
# 3              4.6           3.1           46.0            1.5           0.2
# 4              5.0           3.6           50.0            1.4           0.2
# ..             ...           ...            ...            ...           ...
# 145            6.7           3.0           67.0            5.2           2.3
# 146            6.3           2.5           63.0            5.0           1.9
# 147            6.5           3.0           65.0            5.2           2.0
# 148            6.2           3.4           62.0            5.4           2.3
# 149            5.9           3.0           59.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# ...

# %%
myString = 'Iris-setosa'
myString.lower()
# Out:
# 'iris-setosa'

# %%
myList = []
for val in df.Species:
  myList.append(val.upper())
df['Species_upper'] = myList
df
# Out:
#      SepalLengthCm  SepalWidthCm  SepalLengthMm  PetalLengthCm  PetalWidthCm  \
# 0              5.1           3.5           51.0            1.4           0.2
# 1              4.9           3.0           49.0            1.4           0.2
# 2              4.7           3.2           47.0            1.3           0.2
# 3              4.6           3.1           46.0            1.5           0.2
# 4              5.0           3.6           50.0            1.4           0.2
# ..             ...           ...            ...            ...           ...
# 145            6.7           3.0           67.0            5.2           2.3
# 146            6.3           2.5           63.0            5.0           1.9
# 147            6.5           3.0           65.0            5.2           2.0
# 148            6.2           3.4           62.0            5.4           2.3
# 149            5.9           3.0           59.0            5.1           1.8
#
# ...

# %%
df['Species_lower'] = df.Species.apply(str.upper)
df
# Out:
#      SepalLengthCm  SepalWidthCm  SepalLengthMm  PetalLengthCm  PetalWidthCm  \
# 0              5.1           3.5           51.0            1.4           0.2
# 1              4.9           3.0           49.0            1.4           0.2
# 2              4.7           3.2           47.0            1.3           0.2
# 3              4.6           3.1           46.0            1.5           0.2
# 4              5.0           3.6           50.0            1.4           0.2
# ..             ...           ...            ...            ...           ...
# 145            6.7           3.0           67.0            5.2           2.3
# 146            6.3           2.5           63.0            5.0           1.9
# 147            6.5           3.0           65.0            5.2           2.0
# 148            6.2           3.4           62.0            5.4           2.3
# 149            5.9           3.0           59.0            5.1           1.8
#
# ...

# %%
ddf = df[my_filter][['Species', 'SepalLengthCm']]
ddf
